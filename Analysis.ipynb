# %%
import matplotlib.pyplot as plt
import pandas as pd
import visual

# %% [markdown]
# ## 1. Fix Results

# %%
df_results_fix_20 = pd.read_csv(f'./results/Fix/data/data_fix_n20.csv')
print(df_results_fix_20[['Blocking Pairs', 'Sum_Profit', 'Sum_ETA']].describe())

visual.boxplot(df_results_fix_20, 'Blocking Pairs', 20, 100000, 'Fix')
visual.boxplot(df_results_fix_20, 'Sum_Profit', 20, 100000, 'Fix')
visual.boxplot(df_results_fix_20, 'Sum_ETA', 20, 100000, 'Fix')

visual.barchart_1dimension(df_results_fix_20, 'Blocking Pairs', 20, 100000,
                    'Fix')
visual.barchart_1dimension(df_results_fix_20, 'Sum_Profit', 20, 100000, 'Fix')
visual.barchart_1dimension(df_results_fix_20, 'Sum_ETA', 20, 100000, 'Fix')
# Out:
#        Blocking Pairs     Sum_Profit        Sum_ETA
# count   400000.000000  400000.000000  400000.000000
# mean        94.914677    1285.819532      98.646012
# std         18.457313     321.645955      11.854327
# min         23.000000     433.000000      40.000000
# 25%         82.000000    1000.000000      91.000000
# 50%         94.000000    1239.000000      99.000000
# 75%        107.000000    1599.000000     107.000000
# max        210.000000    1913.000000     149.000000

# %%
df_results_fix_40 = pd.read_csv(f'./results/Fix/data/data_fix_n40.csv')
print(df_results_fix_40[['Blocking Pairs', 'Sum_Profit', 'Sum_ETA']].describe())



visual.boxplot(df_results_fix_40, 'Blocking Pairs', 40, 100000, 'Fix')
visual.boxplot(df_results_fix_40, 'Sum_Profit', 40, 100000, 'Fix')
visual.boxplot(df_results_fix_40, 'Sum_ETA', 40, 100000, 'Fix')

visual.barchart_1dimension(df_results_fix_40, 'Blocking Pairs', 40, 100000,
                    'Fix')
visual.barchart_1dimension(df_results_fix_40, 'Sum_Profit', 40, 100000, 'Fix')
visual.barchart_1dimension(df_results_fix_40, 'Sum_ETA', 40, 100000, 'Fix')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 df_results_fix_40 = pd.read_csv(f'./results/Fix/data/data_fix_n40.csv')
#       2 print(df_results_fix_40[['Blocking Pairs', 'Sum_Profit', 'Sum_ETA']].describe())
#       6 visual.boxplot(df_results_fix_40, 'Blocking Pairs', 40, 100000, 'Fix')
#
# File ~/miniforge3/envs/pm/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
df_results_fix_60 = pd.read_csv(f'./results/Fix/data/data_fix_n60.csv')
print(df_results_fix_60[['Blocking Pairs', 'Sum_Profit', 'Sum_ETA']].describe())



visual.boxplot(df_results_fix_60, 'Blocking Pairs', 60, 100000, 'Fix')
visual.boxplot(df_results_fix_60, 'Sum_Profit', 60, 100000, 'Fix')
visual.boxplot(df_results_fix_60, 'Sum_ETA', 60, 100000, 'Fix')

visual.barchart_1dimension(df_results_fix_60, 'Blocking Pairs', 60, 100000,
                    'Fix')
visual.barchart_1dimension(df_results_fix_60, 'Sum_Profit', 60, 100000, 'Fix')
visual.barchart_1dimension(df_results_fix_60, 'Sum_ETA', 60, 100000, 'Fix')

# %%
df_results_fix_80 = pd.read_csv(f'./results/Fix/data/data_fix_n80.csv')
print(df_results_fix_80[['Blocking Pairs', 'Sum_Profit', 'Sum_ETA']].describe())



visual.boxplot(df_results_fix_80, 'Blocking Pairs', 80, 100000, 'Fix')
visual.boxplot(df_results_fix_80, 'Sum_Profit', 80, 100000, 'Fix')
visual.boxplot(df_results_fix_80, 'Sum_ETA', 80, 100000, 'Fix')

visual.barchart_1dimension(df_results_fix_80, 'Blocking Pairs', 80, 100000,
                    'Fix')
visual.barchart_1dimension(df_results_fix_80, 'Sum_Profit', 80, 100000, 'Fix')
visual.barchart_1dimension(df_results_fix_80, 'Sum_ETA', 80, 100000, 'Fix')

# %%
df_results_fix_100 = pd.read_csv(f'./results/Fix/data/data_fix_n100.csv')
print(df_results_fix_100[['Blocking Pairs', 'Sum_Profit', 'Sum_ETA']].describe())



visual.boxplot(df_results_fix_100, 'Blocking Pairs', 100, 100000, 'Fix')
visual.boxplot(df_results_fix_100, 'Sum_Profit', 100, 100000, 'Fix')
visual.boxplot(df_results_fix_100, 'Sum_ETA', 100, 100000, 'Fix')

visual.barchart_1dimension(df_results_fix_100, 'Blocking Pairs', 100, 100000,
                    'Fix')
visual.barchart_1dimension(df_results_fix_100, 'Sum_Profit', 100, 100000, 'Fix')
visual.barchart_1dimension(df_results_fix_100, 'Sum_ETA', 100, 100000, 'Fix')

# %% [markdown]
# ## 2. Shuffle Results

# %%
df_results_shuffle_20 = pd.read_csv(f'./results/Shuffle/data/data_shuffle_n20.csv')
print(df_results_shuffle_20[['Blocking Pairs', 'Sum_Profit', 'Sum_ETA']].describe())

visual.boxplot(df_results_shuffle_20, 'Blocking Pairs', 20, 100000, 'Shuffle')
visual.boxplot(df_results_shuffle_20, 'Sum_Profit', 20, 100000, 'Shuffle')
visual.boxplot(df_results_shuffle_20, 'Sum_ETA', 20, 100000, 'Shuffle')

visual.barchart_1dimension(df_results_shuffle_20, 'Blocking Pairs', 20, 100000,
                    'Shuffle')
visual.barchart_1dimension(df_results_shuffle_20, 'Sum_Profit', 20, 100000, 'Shuffle')
visual.barchart_1dimension(df_results_shuffle_20, 'Sum_ETA', 20, 100000, 'Shuffle')

# %%
df_results_shuffle_40 = pd.read_csv(f'./results/Shuffle/data/data_shuffle_n40.csv')
print(df_results_shuffle_40[['Blocking Pairs', 'Sum_Profit', 'Sum_ETA']].describe())

visual.boxplot(df_results_shuffle_40, 'Blocking Pairs', 40, 100000, 'Shuffle')
visual.boxplot(df_results_shuffle_40, 'Sum_Profit', 40, 100000, 'Shuffle')
visual.boxplot(df_results_shuffle_40, 'Sum_ETA', 40, 100000, 'Shuffle')

visual.barchart_1dimension(df_results_shuffle_40, 'Blocking Pairs', 40, 100000,
                    'Shuffle')
visual.barchart_1dimension(df_results_shuffle_40, 'Sum_Profit', 40, 100000, 'Shuffle')
visual.barchart_1dimension(df_results_shuffle_40, 'Sum_ETA', 40, 100000, 'Shuffle')

# %%
df_results_shuffle_60 = pd.read_csv(f'./results/Shuffle/data/data_shuffle_n60.csv')
print(df_results_shuffle_60[['Blocking Pairs', 'Sum_Profit', 'Sum_ETA']].describe())

visual.boxplot(df_results_shuffle_60, 'Blocking Pairs', 60, 100000, 'Shuffle')
visual.boxplot(df_results_shuffle_60, 'Sum_Profit', 60, 100000, 'Shuffle')
visual.boxplot(df_results_shuffle_60, 'Sum_ETA', 60, 100000, 'Shuffle')

visual.barchart_1dimension(df_results_shuffle_60, 'Blocking Pairs', 60, 100000,
                    'Shuffle')
visual.barchart_1dimension(df_results_shuffle_60, 'Sum_Profit', 60, 100000, 'Shuffle')
visual.barchart_1dimension(df_results_shuffle_60, 'Sum_ETA', 60, 100000, 'Shuffle')

# %%
df_results_shuffle_80 = pd.read_csv(f'./results/Shuffle/data/data_shuffle_n80.csv')
print(df_results_shuffle_80[['Blocking Pairs', 'Sum_Profit', 'Sum_ETA']].describe())

visual.boxplot(df_results_shuffle_80, 'Blocking Pairs', 80, 100000, 'Shuffle')
visual.boxplot(df_results_shuffle_80, 'Sum_Profit', 80, 100000, 'Shuffle')
visual.boxplot(df_results_shuffle_80, 'Sum_ETA', 80, 100000, 'Shuffle')

visual.barchart_1dimension(df_results_shuffle_80, 'Blocking Pairs', 80, 100000,
                    'Shuffle')
visual.barchart_1dimension(df_results_shuffle_80, 'Sum_Profit', 80, 100000, 'Shuffle')
visual.barchart_1dimension(df_results_shuffle_80, 'Sum_ETA', 80, 100000, 'Shuffle')

# %%
df_results_shuffle_100 = pd.read_csv(f'./results/Shuffle/data/data_shuffle_n100.csv')
print(df_results_shuffle_100[['Blocking Pairs', 'Sum_Profit', 'Sum_ETA']].describe())

visual.boxplot(df_results_shuffle_100, 'Blocking Pairs', 100, 100000, 'Shuffle')
visual.boxplot(df_results_shuffle_100, 'Sum_Profit', 100, 100000, 'Shuffle')
visual.boxplot(df_results_shuffle_100, 'Sum_ETA', 100, 100000, 'Shuffle')

visual.barchart_1dimension(df_results_shuffle_100, 'Blocking Pairs', 100, 100000,
                    'Shuffle')
visual.barchart_1dimension(df_results_shuffle_100, 'Sum_Profit', 100, 100000, 'Shuffle')
visual.barchart_1dimension(df_results_shuffle_100, 'Sum_ETA', 100, 100000, 'Shuffle')

# %% [markdown]
# ## 3. Scalability

# %%
df_run_time = pd.read_csv(f'./results/run_time.csv')
df_run_time
# Out:
#     Runs     n=  Run Time All in s Run Time All in hh:mm:ss  \
# 0      0    100           0.076988                 00:00:00
# 1      1    200           0.504678                 00:00:01
# 2      2    400           3.270675                 00:00:03
# 3      3    600          10.831332                 00:00:11
# 4      4    800          21.668450                 00:00:22
# 5      5   1000          41.486592                 00:00:41
# 6      6   2000         261.799138                 00:04:22
# 7      7   4000        2101.397921                 00:35:01
# 8      8   6000        8205.666376                 02:16:46
# 9      9   8000       25973.561600                 07:12:54
# 10    10  10000       70457.361020                 19:34:17
#
#     Run Time Preference Generation in s  \
# 0                              0.020839
# 1                              0.112848
# 2                              0.681641
# 3                              2.001858
# ...

# %% [markdown]
# ## Run Time All

# %%
x = df_run_time['n=']
y = df_run_time['Run Time All in s']
plt.plot(x, y, '-o')
plt.xlabel('n=')
plt.ylim(0,70000)
plt.ylabel('Process Time in seconds')
plt.title('Run Time All')
plt.show()

# %% [markdown]
# ## Run Time ALG

# %%
x = df_run_time['n=']
y = df_run_time['Run Time ALG in s']
plt.plot(x, y, '-o')
plt.xlabel('n=')
plt.ylim(0,70000)
plt.ylabel('Process Time in seconds')
plt.title('Run Time ALG')
plt.show()

# %% [markdown]
# ## Run Time Preference Generation

# %%
x = df_run_time['n=']
y = df_run_time['Run Time Preference Generation in s']
plt.plot(x, y, '-o')
plt.xlabel('n=')
plt.ylim(0,70000)
plt.ylabel('Process Time in seconds')
plt.title('Run Time Preference Generation')
plt.show()

# %% [markdown]
# ## Stacked Preference Generation and ALG

# %%
x = df_run_time['n=']
y_1 = df_run_time['Run Time Preference Generation in s']
y_2 = df_run_time['Run Time ALG in s']

width = 500    # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots(figsize=(10, 5))

ax.bar(x, y_1, width, label='Preference Generation')
ax.bar(x, y_2, width, bottom=y_1,
       label='Algorithm')

ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.legend()

plt.show()

# %% [markdown]
# ## Shares Preference Generation vs ALG

# %%
df_run_share = df_run_time[['n=','Run Time Preference Generation in %', 'Run Time ALG in %']]
df_run_share
# Out:
#        n= Run Time Preference Generation in % Run Time ALG in %
# 0     100                                 27%               73%
# 1     200                                 22%               78%
# 2     400                                 21%               79%
# 3     600                                 18%               82%
# 4     800                                 20%               80%
# 5    1000                                 20%               80%
# 6    2000                                 22%               78%
# 7    4000                                 21%               79%
# 8    6000                                 17%               83%
# 9    8000                                 13%               87%
# 10  10000                                  9%               91%
